# %%
import pandas as pd

# %%
data = pd.DataFrame({"Name": ["Sam", "Ram"],"Age":[20,22]}, index=["Student_One", "Student_Two"])

# %%
data
# Out:
#             Name  Age
# Student_One  Sam   20
# Student_Two  Ram   22

# %%
# Series
pd.Series([10,20,30], index=["One","two","Three"], name="My Table")
# Out:
# One      10
# two      20
# Three    30
# Name: My Table, dtype: int64

# %%
# Read from csv
my_data = pd.read_csv("../Housing_Price_Model/datasets/melb_data.csv")
my_data.head(5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
my_data.shape
# Out:
# (13580, 21)

# %%
my_data.head(5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
my_data["Address"][0]
# Out:
# '85 Turner St'

# %%
my_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
my_data.iloc[0, [1,2,3]]
# Out:
# Address    85 Turner St
# Rooms                 2
# Type                  h
# Name: 0, dtype: object

# %%
my_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
my_data.loc[0:5, ["Distance","Postcode"]]
# Out:
#    Distance  Postcode
# 0       2.5    3067.0
# 1       2.5    3067.0
# 2       2.5    3067.0
# 3       2.5    3067.0
# 4       2.5    3067.0
# 5       2.5    3067.0

# %%
my_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
my_data.set_index("Address")
# Out:
#                          Suburb  Rooms Type      Price Method   SellerG  \
# Address
# 85 Turner St         Abbotsford      2    h  1480000.0      S    Biggin
# 25 Bloomburg St      Abbotsford      2    h  1035000.0      S    Biggin
# 5 Charles St         Abbotsford      3    h  1465000.0     SP    Biggin
# 40 Federation La     Abbotsford      3    h   850000.0     PI    Biggin
# 55a Park St          Abbotsford      4    h  1600000.0     VB    Nelson
# ...                         ...    ...  ...        ...    ...       ...
# 12 Strada Cr      Wheelers Hill      4    h  1245000.0      S     Barry
# 77 Merrett Dr      Williamstown      3    h  1031000.0     SP  Williams
# 83 Power St        Williamstown      3    h  1170000.0      S     Raine
# 96 Verdon St       Williamstown      4    h  2500000.0     PI   Sweeney
# 6 Agnes St           Yarraville      4    h  1285000.0     SP   Village
#
#                         Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# Address
# ...

# %%
my_data
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
my_data.loc[(my_data["Distance"]> 2) & (my_data["Distance"]<4)]
# Out:
#                Suburb           Address  Rooms Type      Price Method  \
# 0          Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          Abbotsford       55a Park St      4    h  1600000.0     VB
# ...               ...               ...    ...  ...        ...    ...
# 13420   Fitzroy North  211 Scotchmer St      4    h  1620000.0      S
# 13490     Middle Park     81 Erskine St      3    h  2090000.0      S
# 13521  Port Melbourne      44 Garton St      4    t  2455000.0     SP
# 13522  Port Melbourne     201 Stokes St      2    h  1515000.0     SP
# 13531        Richmond     170 Coppin St      4    h  1800000.0      S
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
my_data.loc[my_data["SellerG"].isin(["Nelson", "Biggin"])]
# Out:
#            Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
# ...           ...               ...    ...  ...        ...    ...     ...
# 13531    Richmond     170 Coppin St      4    h  1800000.0      S  Biggin
# 13534     Rosanna   179 Beverley Rd      3    h  1224000.0      S  Nelson
# 13535     Rosanna    30 Phillips Cr      4    h  1426000.0      S  Nelson
# 13563   Thornbury      201 Gooch St      3    h  1271000.0      S  Nelson
# 13567    Viewbank     149 Graham Rd      5    h  1316000.0     SP  Nelson
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
my_data.loc[my_data['BuildingArea'].notnull()]
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 1        Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4        Abbotsford      55a Park St      4    h  1600000.0     VB
# 6        Abbotsford     124 Yarra St      3    h  1876000.0      S
# 7        Abbotsford    98 Charles St      2    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 13572      Watsonia    76 Kenmare St      2    h   650000.0     PI
# 13573      Werribee      5 Nuragi Ct      4    h   635000.0      S
# 13576  Williamstown    77 Merrett Dr      3    h  1031000.0     SP
# 13578  Williamstown     96 Verdon St      4    h  2500000.0     PI
# 13579    Yarraville       6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# ...

# %%
my_data["Price"] = 100

# %%
my_data
# Out:
#               Suburb           Address  Rooms Type  Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h    100      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h    100      S    Biggin
# 2         Abbotsford      5 Charles St      3    h    100     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h    100     PI    Biggin
# 4         Abbotsford       55a Park St      4    h    100     VB    Nelson
# ...              ...               ...    ...  ...    ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h    100      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h    100     SP  Williams
# 13577   Williamstown       83 Power St      3    h    100      S     Raine
# 13578   Williamstown      96 Verdon St      4    h    100     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h    100     SP   Village
#
# ...

# %%
my_data["check-in"] = "sam"

# %%
my_data
# Out:
#               Suburb           Address  Rooms Type  Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h    100      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h    100      S    Biggin
# 2         Abbotsford      5 Charles St      3    h    100     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h    100     PI    Biggin
# 4         Abbotsford       55a Park St      4    h    100     VB    Nelson
# ...              ...               ...    ...  ...    ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h    100      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h    100     SP  Williams
# 13577   Williamstown       83 Power St      3    h    100      S     Raine
# 13578   Williamstown      96 Verdon St      4    h    100     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h    100     SP   Village
#
# ...
