# %%
import pandas as pd

pd.DataFrame({"Name": ["sam","ram"],"Age":[20,22]}, index=["StudOne", "StudeTwo"])
# Out:
#          Name  Age
# StudOne   sam   20
# StudeTwo  ram   22

# %%
pd.Series([10,20,30], name="my_series",index=["One", "Two","Three"])
# Out:
# One      10
# Two      20
# Three    30
# Name: my_series, dtype: int64

# %%
data = pd.read_csv("../Housing_Price_Model/datasets/melb_data.csv")

data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
test = pd.DataFrame({"Name": ["sam","ram"],"Age":[20,22]})

# %%
test
# Out:
#   Name  Age
# 0  sam   20
# 1  ram   22

# %%
test["Name"][1]
# Out:
# 'ram'

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
data.Address
# Out:
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %%
data.iloc[0, 1]
# Out:
# '85 Turner St'

# %%
data.loc[0,"Address"]
# Out:
# '85 Turner St'

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
data.loc[(data["Landsize"]> 99) & (data["Landsize"]<101)]
data["eccetic"] = True

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
def operations(row):
   # row = "sam"
    row = 100
    return row
    

new_data = data.Price.map(operations)

new_data.head()
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# Name: Price, dtype: int64

# %%
def operations(row):
    row.Price = 100
    return row

data.apply(operations, axis="columns")
# Out:
#               Suburb           Address  Rooms Type  Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h    100      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h    100      S    Biggin
# 2         Abbotsford      5 Charles St      3    h    100     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h    100     PI    Biggin
# 4         Abbotsford       55a Park St      4    h    100     VB    Nelson
# ...              ...               ...    ...  ...    ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h    100      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h    100     SP  Williams
# 13577   Williamstown       83 Power St      3    h    100      S     Raine
# 13578   Williamstown      96 Verdon St      4    h    100     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h    100     SP   Village
#
# ...

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
def tester(row):
    row["NEW"] = 0
    return row
data.apply(tester, axis=1)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      0    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      0    h  1035000.0      S
# 2         Abbotsford      5 Charles St      0    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      0    h   850000.0     PI
# 4         Abbotsford       55a Park St      0    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      0    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      0    h  1031000.0     SP
# 13577   Williamstown       83 Power St      0    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      0    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      0    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Landsize  BuildingArea  \
# ...

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      0    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      0    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      0    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      0    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      0    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
data.groupby("Distance").Price.min()
# Out:
# Distance
# 0.0      387000.0
# 0.7      422000.0
# 1.2      370000.0
# 1.3      885000.0
# 1.5      503000.0
#           ...
# 45.2     650000.0
# 45.9     426000.0
# 47.3     410500.0
# 47.4     817000.0
# 48.1    1355000.0
# Name: Price, Length: 202, dtype: float64

# %%
data = data.head(5)

# %%
data
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      0    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      0    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      0    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      0    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      0    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
data.groupby(["Landsize", "Rooms"]).Price.apply(lambda x : x+100)
# Out:
# Landsize  Rooms
# 94.0      0      3     850100.0
# 120.0     0      4    1600100.0
# 134.0     0      2    1465100.0
# 156.0     0      1    1035100.0
# 202.0     0      0    1480100.0
# Name: Price, dtype: float64
